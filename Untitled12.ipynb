# %% [markdown]
# <a href="https://colab.research.google.com/github/ommalewar8154-wq/DAA-Project/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import kagglehub

# %%
# Download dataset from Kaggle
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

train_dir = os.path.join(path, "Training")
test_dir = os.path.join(path, "Testing")

print("Training Path:", train_dir)
print("Testing Path:", test_dir)
# Out:
# Using Colab cache for faster access to the 'brain-tumor-mri-dataset' dataset.
# Training Path: /kaggle/input/brain-tumor-mri-dataset/Training
# Testing Path: /kaggle/input/brain-tumor-mri-dataset/Testing
